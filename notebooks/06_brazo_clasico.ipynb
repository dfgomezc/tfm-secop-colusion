# %% [markdown]
# # El brazo clásico: qué se obtiene sin entrenar nada
#
# Evalúa como detectores las técnicas clásicas de grafos, que hasta este punto
# funcionaban como ingeniería de variables. Tres ordenamientos construidos sin
# entrenar: PageRank puro, recuento de banderas rojas estructurales y número de
# contratos.
#
# El resultado es el más incómodo y probablemente el más valioso del capítulo:
# contar contratos supera a PageRank, y las banderas rojas quedan por debajo del
# azar. Ninguna de las dos cosas es un fracaso del método, y el cuaderno lo
# explica.

# %%
import sys, os
sys.path.insert(0, os.path.abspath(".."))
from tfm import ejecutar, rutas
ejecutar.situacion()

# %%
ejecutar.correr('tfm.modelos.brazo_clasico')

# %% [markdown]
# ## Los ordenamientos evaluados
#
# Mismas métricas y mismo conjunto de prueba que los modelos entrenados, que es lo que permite compararlos.

# %%
display(ejecutar.tabla('ordenamientos'))

# %% [markdown]
# ## Diagnóstico bandera a bandera
#
# Que las cuatro queden por debajo de 0,50 individualmente descarta que el problema sea la agregación.

# %%
display(ejecutar.tabla('banderas_rojas'))
