# %% [markdown]
# # Solapamiento entre paradigmas y métricas operativas
#
# Dos análisis que traducen la comparación a la decisión que un organismo de
# control toma de verdad.
#
# El solapamiento mide cuántos actores comparten la lista corta del modelo y el
# conjunto señalado por la estructura. La respuesta —uno de 1.211, por debajo de
# lo que cabría esperar al azar— es la base empírica de la recomendación híbrida,
# que antes era un argumento de conveniencia.
#
# Las métricas operativas responden a cuántos casos revisar y con qué acierto.

# %%
import sys, os
sys.path.insert(0, os.path.abspath(".."))
from tfm import ejecutar, rutas
ejecutar.situacion()

# %%
ejecutar.correr('tfm.modelos.solapamiento')

# %% [markdown]
# ## Solapamiento y perfil de las tres zonas

# %%
display(ejecutar.tabla('solapamiento'))
display(ejecutar.tabla('zonas'))

# %% [markdown]
# ## Precisión y lift según el tamaño de la lista

# %%
ejecutar.correr('tfm.modelos.metricas_operativas')
display(ejecutar.tabla('curva_lift'))

# %% [markdown]
# ## Tablas seudonimizadas
#
# Los actores se citan bajo seudónimo.

# %%
ejecutar.correr('tfm.modelos.tablas_seudonimizadas')
